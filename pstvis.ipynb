# %%
import numpy as np
import seaborn as sns
import matplotlib.pylab as plt

# uniform_data = np.random.rand(10, 12)
# ax = sns.heatmap(uniform_data, linewidth=0.5)
# plt.show()

# %%
class S:
    def __init__(self, mg, eg):
        self.mg = mg
        self.eg = eg

# %%
tuned = [[S(0, 0), S(0, 0), S(0, 0), S(0, 0), S(0, 0), S(0, 0), S(0, 0), S(0, 0), S(2, -8), S(4, -6), S(11, 9), S(18, 5), S(16, 16), S(21, 6), S(9, -6), S(-3, -18), S(-9, -9), S(-15, -7), S(11, -10), S(15, 5), S(31, 2), S(23, 3), S(6, -8), S(-20, -5), S(-3, 7), S(-20, 1), S(8, -8), S(19, -2), S(39, -14), S(17, -13), S(2, -11), S(-5, -6), S(11, 12), S(-4, 6), S(-11, 2), S(2, -6), S(11, -5), S(0, -4), S(-12, 14), S(5, 9), S(3, 27), S(-11, 18), S(-6, 19), S(22, 29), S(-8, 30), S(-5, 9), S(-14, 8), S(-11, 14), S(-7, -1), S(6, -14), S(-2, 13), S(-11, 22), S(4, 24), S(-14, 17), S(10, 7), S(-9, 7), S(0, 0), S(0, 0), S(0, 0), S(0, 0), S(0, 0), S(0, 0), S(0, 0), S(0, 0)], [S(-175, -96), S(-92, -65), S(-74, -49), S(-73, -21), S(-73, -21), S(-74, -49), S(-92, -65), S(-175, -96), S(-77, -67), S(-41, -54), S(-27, -18), S(-15, 8), S(-15, 8), S(-27, -18), S(-41, -54), S(-77, -67), S(-61, -40), S(-17, -27), S(6, -8), S(12, 29), S(12, 29), S(6, -8), S(-17, -27), S(-61, -40), S(-35, -35), S(8, -2), S(40, 13), S(49, 28), S(49, 28), S(40, 13), S(8, -2), S(-35, -35), S(-34, -45), S(13, -16), S(44, 9), S(51, 39), S(51, 39), S(44, 9), S(13, -16), S(-34, -45), S(-9, -51), S(22, -44), S(58, -16), S(53, 17), S(53, 17), S(58, -16), S(22, -44), S(-9, -51), S(-67, -69), S(-27, -50), S(4, -51), S(37, 12), S(37, 12), S(4, -51), S(-27, -50), S(-67, -69), S(-201, -100), S(-83, -88), S(-56, -56), S(-26, -17), S(-26, -17), S(-56, -56), S(-83, -88), S(-201, -100)], [S(-37, -40), S(-4, -21), S(-6, -26), S(-16, -8), S(-16, -8), S(-6, -26), S(-4, -21), S(-37, -40), S(-11, -26), S(6, -9), S(13, -12), S(3, 1), S(3, 1), S(13, -12), S(6, -9), S(-11, -26), S(-5, -11), S(15, -1), S(-4, -1), S(12, 7), S(12, 7), S(-4, -1), S(15, -1), S(-5, -11), S(-4, -14), S(8, -4), S(18, 0), S(27, 12), S(27, 12), S(18, 0), S(8, -4), S(-4, -14), S(-8, -12), S(20, -1), S(15, -10), S(22, 11), S(22, 11), S(15, -10), S(20, -1), S(-8, -12), S(-11, -21), S(4, 4), S(1, 3), S(8, 4), S(8, 4), S(1, 3), S(4, 4), S(-11, -21), S(-12, -22), S(-10, -14), S(4, -1), S(0, 1), S(0, 1), S(4, -1), S(-10, -14), S(-12, -22), S(-34, -32), S(1, -29), S(-10, -26), S(-16, -17), S(-16, -17), S(-10, -26), S(1, -29), S(-34, -32)], [S(-31, -9), S(-20, -13), S(-14, -10), S(-5, -9), S(-5, -9), S(-14, -10), S(-20, -13), S(-31, -9), S(-21, -12), S(-13, -9), S(-8, -1), S(6, -2), S(6, -2), S(-8, -1), S(-13, -9), S(-21, -12), S(-25, 6), S(-11, -8), S(-1, -2), S(3, -6), S(3, -6), S(-1, -2), S(-11, -8), S(-25, 6), S(-13, -6), S(-5, 1), S(-4, -9), S(-6, 7), S(-6, 7), S(-4, -9), S(-5, 1), S(-13, -6), S(-27, -5), S(-15, 8), S(-4, 7), S(3, -6), S(3, -6), S(-4, 7), S(-15, 8), S(-27, -5), S(-22, 6), S(-2, 1), S(6, -7), S(12, 10), S(12, 10), S(6, -7), S(-2, 1), S(-22, 6), S(-2, 4), S(12, 5), S(16, 20), S(18, -5), S(18, -5), S(16, 20), S(12, 5), S(-2, 4), S(-17, 18), S(-19, 0), S(-1, 19), S(9, 13), S(9, 13), S(-1, 19), S(-19, 0), S(-17, 18)], [S(3, -69), S(-5, -57), S(-5, -47), S(4, -26), S(4, -26), S(-5, -47), S(-5, -57), S(3, -69), S(-3, -54), S(5, -31), S(8, -22), S(12, -4), S(12, -4), S(8, -22), S(5, -31), S(-3, -54), S(-3, -39), S(6, -18), S(13, -9), S(7, 3), S(7, 3), S(13, -9), S(6, -18), S(-3, -39), S(4, -23), S(5, -3), S(9, 13), S(8, 24), S(8, 24), S(9, 13), S(5, -3), S(4, -23), S(0, -29), S(14, -6), S(12, 9), S(5, 21), S(5, 21), S(12, 9), S(14, -6), S(0, -29), S(-4, -38), S(10, -18), S(6, -11), S(8, 1), S(8, 1), S(6, -11), S(10, -18), S(-4, -38), S(-5, -50), S(6, -27), S(10, -24), S(8, -8), S(8, -8), S(10, -24), S(6, -27), S(-5, -50), S(-2, -74), S(-2, -52), S(1, -43), S(-2, -34), S(-2, -34), S(1, -43), S(-2, -52), S(-2, -74)], [S(271, 1), S(327, 45), S(271, 85), S(198, 76), S(198, 76), S(271, 85), S(327, 45), S(271, 1), S(278, 53), S(303, 100), S(234, 133), S(179, 135), S(179, 135), S(234, 133), S(303, 100), S(278, 53), S(195, 88), S(258, 130), S(169, 169), S(120, 175), S(120, 175), S(169, 169), S(258, 130), S(195, 88), S(164, 103), S(190, 156), S(138, 172), S(98, 172), S(98, 172), S(138, 172), S(190, 156), S(164, 103), S(154, 96), S(179, 166), S(105, 199), S(70, 199), S(70, 199), S(105, 199), S(179, 166), S(154, 96), S(123, 92), S(145, 172), S(81, 184), S(31, 191), S(31, 191), S(81, 184), S(145, 172), S(123, 92), S(88, 47), S(120, 121), S(65, 116), S(33, 131), S(33, 131), S(65, 116), S(120, 121), S(88, 47), S(59, 11), S(89, 59), S(45, 73), S(-1, 78), S(-1, 78), S(45, 73), S(89, 59), S(59, 11)]]

# %%
tuned_246 = [[S(0, 0), S(0, 0), S(0, 0), S(0, 0), S(0, 0), S(0, 0), S(0, 0), S(0, 0), S(-18, 14), S(-22, 21), S(-7, 35), S(20, 31), S(22, 26), S(44, 30), S(34, 9), S(2, 0), S(-26, -4), S(-19, 13), S(-12, 9), S(6, 12), S(21, 16), S(11, 29), S(22, 1), S(-4, 0), S(-28, 18), S(-31, 26), S(0, 6), S(7, -6), S(12, -5), S(22, 14), S(18, 16), S(10, 3), S(0, 39), S(-13, 33), S(-4, 28), S(8, -21), S(28, 8), S(0, 23), S(15, 41), S(32, 23), S(19, 54), S(6, 45), S(19, 46), S(20, 15), S(19, 54), S(22, 36), S(13, 35), S(16, 41), S(20, 26), S(33, 13), S(25, 40), S(16, 49), S(31, 51), S(13, 44), S(37, 34), S(-3, 34), S(0, 0), S(0, 0), S(0, 0), S(0, 0), S(0, 0), S(0, 0), S(0, 0), S(0, 0)], [S(-148, -69), S(-65, -41), S(-53, -42), S(-61, -2), S(-61, -2), S(-53, -42), S(-65, -41), S(-148, -69), S(-56, -40), S(-68, -28), S(-34, -19), S(-13, -19), S(-13, -19), S(-34, -19), S(-68, -28), S(-56, -40), S(-55, -30), S(-11, -21), S(-21, -13), S(4, 25), S(4, 25), S(-21, -13), S(-11, -21), S(-55, -30), S(-21, -10), S(22, 23), S(18, 39), S(22, 39), S(22, 39), S(18, 39), S(22, 23), S(-21, -10), S(-7, -18), S(36, 11), S(56, 36), S(41, 57), S(41, 57), S(56, 36), S(36, 11), S(-7, -18), S(18, -24), S(49, -17), S(85, 11), S(80, 35), S(80, 35), S(85, 11), S(49, -17), S(18, -24), S(-40, -42), S(0, -23), S(31, -24), S(64, 39), S(64, 39), S(31, -24), S(0, -23), S(-40, -42), S(-174, -73), S(-56, -61), S(-29, -29), S(1, 10), S(1, 10), S(-29, -29), S(-56, -61), S(-174, -73)], [S(-19, -25), S(23, 1), S(-11, -5), S(-35, -8), S(-35, -8), S(-11, -5), S(23, 1), S(-19, -25), S(16, -18), S(9, -23), S(13, -20), S(-24, -8), S(-24, -8), S(13, -20), S(9, -23), S(16, -18), S(-12, -22), S(12, -18), S(-26, -2), S(-7, 16), S(-7, 16), S(-26, -2), S(12, -18), S(-12, -22), S(23, -29), S(-2, -27), S(-9, 0), S(17, 10), S(17, 10), S(-9, 0), S(-2, -27), S(23, -29), S(-6, 12), S(0, 1), S(34, -15), S(34, 8), S(34, 8), S(34, -15), S(0, 1), S(-6, 12), S(16, 6), S(31, 10), S(28, 15), S(35, -14), S(35, -14), S(28, 15), S(31, 10), S(16, 6), S(15, 5), S(-15, 13), S(21, -10), S(0, 12), S(0, 12), S(21, -10), S(-15, 13), S(15, 5), S(-26, -5), S(1, -4), S(-16, 1), S(-32, 4), S(-32, 4), S(-16, 1), S(1, -4), S(-26, -5)], [S(-9, -31), S(-2, -39), S(-24, 3), S(-20, -16), S(-20, -16), S(-24, 3), S(-2, -39), S(-9, -31), S(-48, -28), S(-20, -29), S(-30, -28), S(-21, -29), S(-21, -29), S(-30, -28), S(-20, -29), S(-48, -28), S(-34, 0), S(5, -30), S(-28, -14), S(-24, -33), S(-24, -33), S(-28, -14), S(5, -30), S(-34, 0), S(-12, 21), S(-1, -4), S(-21, 4), S(-33, 11), S(-33, 11), S(-21, 4), S(-1, -4), S(-12, 21), S(0, 22), S(12, 18), S(-3, 31), S(25, 21), S(25, 21), S(-3, 31), S(12, 18), S(0, 22), S(4, 30), S(25, 17), S(33, 20), S(27, 32), S(27, 32), S(33, 20), S(25, 17), S(4, 30), S(12, 31), S(16, 32), S(15, 45), S(45, 22), S(45, 22), S(15, 45), S(16, 32), S(12, 31), S(10, 25), S(8, 0), S(24, 35), S(33, 23), S(33, 23), S(24, 35), S(8, 0), S(10, 25)], [S(-13, -75), S(-25, -76), S(-32, -74), S(-10, -51), S(-10, -51), S(-32, -74), S(-25, -76), S(-13, -75), S(7, -81), S(-10, -58), S(-14, -49), S(-15, -31), S(-15, -31), S(-14, -49), S(-10, -58), S(7, -81), S(1, -64), S(-4, -38), S(-14, -18), S(-20, -24), S(-20, -24), S(-14, -18), S(-4, -38), S(1, -64), S(8, -31), S(11, -2), S(-3, -2), S(-19, 29), S(-19, 29), S(-3, -2), S(11, -2), S(8, -31), S(0, -2), S(14, 17), S(16, 33), S(-3, 48), S(-3, 48), S(16, 33), S(14, 17), S(0, -2), S(23, -11), S(37, 9), S(33, 16), S(35, 28), S(35, 28), S(33, 16), S(37, 9), S(23, -11), S(22, -23), S(-21, 0), S(36, 3), S(30, 18), S(30, 18), S(36, 3), S(-21, 0), S(22, -23), S(25, -60), S(25, -31), S(28, -16), S(25, -7), S(25, -7), S(28, -16), S(25, -31), S(25, -60)], [S(296, 2), S(300, 49), S(254, 58), S(225, 77), S(225, 77), S(254, 58), S(300, 49), S(296, 2), S(268, 67), S(276, 81), S(207, 112), S(168, 119), S(168, 119), S(207, 112), S(276, 81), S(268, 67), S(168, 81), S(231, 103), S(142, 142), S(136, 152), S(136, 152), S(142, 142), S(231, 103), S(168, 81), S(144, 115), S(166, 142), S(123, 172), S(122, 189), S(122, 189), S(123, 172), S(166, 142), S(144, 115), S(179, 123), S(181, 164), S(131, 205), S(97, 210), S(97, 210), S(131, 205), S(181, 164), S(179, 123), S(150, 119), S(172, 199), S(108, 211), S(58, 218), S(58, 218), S(108, 211), S(172, 199), S(150, 119), S(115, 74), S(147, 148), S(92, 143), S(60, 158), S(60, 158), S(92, 143), S(147, 148), S(115, 74), S(86, 38), S(116, 86), S(72, 100), S(26, 105), S(26, 105), S(72, 100), S(116, 86), S(86, 38)]]
it_2 = "localsearch12M_27"

# %%
mg_pawns = np.array([
      0,   0,   0,   0,   0,   0,  0,   0,
     98, 134,  61,  95,  68, 126, 34, -11,
     -6,   7,  26,  31,  65,  56, 25, -20,
    -14,  13,   6,  21,  23,  12, 17, -23,
    -27,  -2,  -5,  12,  17,   6, 10, -25,
    -26,  -4,  -4, -10,   3,   3, 33, -12,
    -35,  -1, -20, -23, -15,  24, 38, -22,
      0,   0,   0,   0,   0,   0,  0,   0,
])
eg_pawns = np.array([
      0,   0,   0,   0,   0,   0,   0,   0,
    178, 173, 158, 134, 147, 132, 165, 187,
     94, 100,  85,  67,  56,  53,  82,  84,
     32,  24,  13,   5,  -2,   4,  17,  17,
     13,   9,  -3,  -7,  -7,  -8,   3,  -1,
      4,   7,  -6,   1,   0,  -5,  -1,  -8,
     13,   8,   8,  10,  13,   0,   2,  -7,
      0,   0,   0,   0,   0,   0,   0,   0,
])
mg_knights = np.array([
    -167, -89, -34, -49,  61, -97, -15, -107,
     -73, -41,  72,  36,  23,  62,   7,  -17,
     -47,  60,  37,  65,  84, 129,  73,   44,
      -9,  17,  19,  53,  37,  69,  18,   22,
     -13,   4,  16,  13,  28,  19,  21,   -8,
     -23,  -9,  12,  10,  19,  17,  25,  -16,
     -29, -53, -12,  -3,  -1,  18, -14,  -19,
    -105, -21, -58, -33, -17, -28, -19,  -23,
])
eg_knights = np.array([
    -58, -38, -13, -28, -31, -27, -63, -99,
    -25,  -8, -25,  -2,  -9, -25, -24, -52,
    -24, -20,  10,   9,  -1,  -9, -19, -41,
    -17,   3,  22,  22,  22,  11,   8, -18,
    -18,  -6,  16,  25,  16,  17,   4, -18,
    -23,  -3,  -1,  15,  10,  -3, -20, -22,
    -42, -20, -10,  -5,  -2, -20, -23, -44,
    -29, -51, -23, -15, -22, -18, -50, -64,
])
mg_bishops = np.array([
    -29,   4, -82, -37, -25, -42,   7,  -8,
    -26,  16, -18, -13,  30,  59,  18, -47,
    -16,  37,  43,  40,  35,  50,  37,  -2,
     -4,   5,  19,  50,  37,  37,   7,  -2,
     -6,  13,  13,  26,  34,  12,  10,   4,
      0,  15,  15,  15,  14,  27,  18,  10,
      4,  15,  16,   0,   7,  21,  33,   1,
    -33,  -3, -14, -21, -13, -12, -39, -21,
])
eg_bishops = np.array([
    -14, -21, -11,  -8, -7,  -9, -17, -24,
     -8,  -4,   7, -12, -3, -13,  -4, -14,
      2,  -8,   0,  -1, -2,   6,   0,   4,
     -3,   9,  12,   9, 14,  10,   3,   2,
     -6,   3,  13,  19,  7,  10,  -3,  -9,
    -12,  -3,   8,  10, 13,   3,  -7, -15,
    -14, -18,  -7,  -1,  4,  -9, -15, -27,
    -23,  -9, -23,  -5, -9, -16,  -5, -17,
])
mg_rooks = np.array([
     32,  42,  32,  51, 63,  9,  31,  43,
     27,  32,  58,  62, 80, 67,  26,  44,
     -5,  19,  26,  36, 17, 45,  61,  16,
    -24, -11,   7,  26, 24, 35,  -8, -20,
    -36, -26, -12,  -1,  9, -7,   6, -23,
    -45, -25, -16, -17,  3,  0,  -5, -33,
    -44, -16, -20,  -9, -1, 11,  -6, -71,
    -19, -13,   1,  17, 16,  7, -37, -26,
])
eg_rooks = np.array([
    13, 10, 18, 15, 12,  12,   8,   5,
    11, 13, 13, 11, -3,   3,   8,   3,
     7,  7,  7,  5,  4,  -3,  -5,  -3,
     4,  3, 13,  1,  2,   1,  -1,   2,
     3,  5,  8,  4, -5,  -6,  -8, -11,
    -4,  0, -5, -1, -7, -12,  -8, -16,
    -6, -6,  0,  2, -9,  -9, -11,  -3,
    -9,  2,  3, -1, -5, -13,   4, -20,
])
mg_queens = np.array([
    -28,   0,  29,  12,  59,  44,  43,  45,
    -24, -39,  -5,   1, -16,  57,  28,  54,
    -13, -17,   7,   8,  29,  56,  47,  57,
    -27, -27, -16, -16,  -1,  17,  -2,   1,
     -9, -26,  -9, -10,  -2,  -4,   3,  -3,
    -14,   2, -11,  -2,  -5,   2,  14,   5,
    -35,  -8,  11,   2,   8,  15,  -3,   1,
     -1, -18,  -9,  10, -15, -25, -31, -50,
])
eg_queens = np.array([
     -9,  22,  22,  27,  27,  19,  10,  20,
    -17,  20,  32,  41,  58,  25,  30,   0,
    -20,   6,   9,  49,  47,  35,  19,   9,
      3,  22,  24,  45,  57,  40,  57,  36,
    -18,  28,  19,  47,  31,  34,  39,  23,
    -16, -27,  15,   6,   9,  17,  10,   5,
    -22, -23, -30, -16, -16, -23, -36, -32,
    -33, -28, -22, -43,  -5, -32, -20, -41,
])
mg_kings = np.array([
    -65,  23,  16, -15, -56, -34,   2,  13,
     29,  -1, -20,  -7,  -8,  -4, -38, -29,
     -9,  24,   2, -16, -20,   6,  22, -22,
    -17, -20, -12, -27, -30, -25, -14, -36,
    -49,  -1, -27, -39, -46, -44, -33, -51,
    -14, -14, -22, -46, -44, -30, -15, -27,
      1,   7,  -8, -64, -43, -16,   9,   8,
    -15,  36,  12, -54,   8, -28,  24,  14,
])
eg_kings = np.array([
    -74, -35, -18, -18, -11,  15,   4, -17,
    -12,  17,  14,  17,  17,  38,  23,  11,
     10,  17,  23,  15,  20,  45,  44,  13,
     -8,  22,  24,  27,  26,  33,  26,   3,
    -18,  -4,  21,  24,  27,  23,   9, -11,
    -19,  -3,  11,  21,  23,  16,   7,  -9,
    -27, -11,   4,  13,  14,   4,  -5, -17,
    -53, -34, -21, -11, -28, -14, -24, -43
])
mg_pawns = mg_pawns.reshape(8, 8)
eg_pawns = eg_pawns.reshape(8, 8)
mg_knights = mg_knights.reshape(8, 8)
eg_knights = eg_knights.reshape(8, 8)
mg_bishops = mg_bishops.reshape(8, 8)
eg_bishops = eg_bishops.reshape(8, 8)
mg_rooks = mg_rooks.reshape(8, 8)
eg_rooks = eg_rooks.reshape(8, 8)
mg_queens = mg_queens.reshape(8, 8)
eg_queens = eg_queens.reshape(8, 8)
mg_kings = mg_kings.reshape(8, 8)
eg_kings = eg_kings.reshape(8, 8)

# %%
tuned_mg_pawns = np.array([s.mg for s in tuned[0]]).reshape(8, 8)
tuned_eg_pawns = np.array([s.eg for s in tuned[0]]).reshape(8, 8)
tuned_mg_knights = np.array([s.mg for s in tuned[1]]).reshape(8, 8)
tuned_eg_knights = np.array([s.eg for s in tuned[1]]).reshape(8, 8)
tuned_mg_bishops = np.array([s.mg for s in tuned[2]]).reshape(8, 8)
tuned_eg_bishops = np.array([s.eg for s in tuned[2]]).reshape(8, 8)
tuned_mg_rooks = np.array([s.mg for s in tuned[3]]).reshape(8, 8)
tuned_eg_rooks = np.array([s.eg for s in tuned[3]]).reshape(8, 8)
tuned_mg_queens = np.array([s.mg for s in tuned[4]]).reshape(8, 8)
tuned_eg_queens = np.array([s.eg for s in tuned[4]]).reshape(8, 8)
tuned_mg_kings = np.array([s.mg for s in tuned[5]]).reshape(8, 8)
tuned_eg_kings = np.array([s.eg for s in tuned[5]]).reshape(8, 8)

# %%
tuned_246_mg_pawns = np.array([s.mg for s in tuned_246[0]]).reshape(8, 8)
tuned_246_eg_pawns = np.array([s.eg for s in tuned_246[0]]).reshape(8, 8)
tuned_246_mg_knights = np.array([s.mg for s in tuned_246[1]]).reshape(8, 8)
tuned_246_eg_knights = np.array([s.eg for s in tuned_246[1]]).reshape(8, 8)
tuned_246_mg_bishops = np.array([s.mg for s in tuned_246[2]]).reshape(8, 8)
tuned_246_eg_bishops = np.array([s.eg for s in tuned_246[2]]).reshape(8, 8)
tuned_246_mg_rooks = np.array([s.mg for s in tuned_246[3]]).reshape(8, 8)
tuned_246_eg_rooks = np.array([s.eg for s in tuned_246[3]]).reshape(8, 8)
tuned_246_mg_queens = np.array([s.mg for s in tuned_246[4]]).reshape(8, 8)
tuned_246_eg_queens = np.array([s.eg for s in tuned_246[4]]).reshape(8, 8)
tuned_246_mg_kings = np.array([s.mg for s in tuned_246[5]]).reshape(8, 8)
tuned_246_eg_kings = np.array([s.eg for s in tuned_246[5]]).reshape(8, 8)

# %%
figure, axis = plt.subplots(6, 6, figsize=(30, 30))
axis[0, 0].imshow(mg_pawns, cmap='inferno', interpolation='none')
axis[0, 0].set_title('MG Pawns')
axis[0, 1].imshow(eg_pawns, cmap='inferno', interpolation='none')
axis[0, 1].set_title('EG Pawns')
axis[1, 0].imshow(mg_knights, cmap='inferno', interpolation='none')
axis[1, 0].set_title('MG Knights')
axis[1, 1].imshow(eg_knights, cmap='inferno', interpolation='none')
axis[1, 1].set_title('EG Knights')
axis[2, 0].imshow(mg_bishops, cmap='inferno', interpolation='none')
axis[2, 0].set_title('MG Bishops')
axis[2, 1].imshow(eg_bishops, cmap='inferno', interpolation='none')
axis[2, 1].set_title('EG Bishops')
axis[3, 0].imshow(mg_rooks, cmap='inferno', interpolation='none')
axis[3, 0].set_title('MG Rooks')
axis[3, 1].imshow(eg_rooks, cmap='inferno', interpolation='none')
axis[3, 1].set_title('EG Rooks')
axis[4, 0].imshow(mg_queens, cmap='inferno', interpolation='none')
axis[4, 0].set_title('MG Queens')
axis[4, 1].imshow(eg_queens, cmap='inferno', interpolation='none')
axis[4, 1].set_title('EG Queens')
axis[5, 0].imshow(mg_kings, cmap='inferno', interpolation='none')
axis[5, 0].set_title('MG Kings')
axis[5, 1].imshow(eg_kings, cmap='inferno', interpolation='none')
axis[5, 1].set_title('EG Kings')
axis[0, 2].imshow(tuned_mg_pawns, cmap='inferno', interpolation='none')
axis[0, 2].set_title('Tuned MG Pawns (33)')
axis[0, 3].imshow(tuned_eg_pawns, cmap='inferno', interpolation='none')
axis[0, 3].set_title('Tuned EG Pawns (33)')
axis[1, 2].imshow(tuned_mg_knights, cmap='inferno', interpolation='none')
axis[1, 2].set_title('Tuned MG Knights (33)')
axis[1, 3].imshow(tuned_eg_knights, cmap='inferno', interpolation='none')
axis[1, 3].set_title('Tuned EG Knights (33)')
axis[2, 2].imshow(tuned_mg_bishops, cmap='inferno', interpolation='none')
axis[2, 2].set_title('Tuned MG Bishops (33)')
axis[2, 3].imshow(tuned_eg_bishops, cmap='inferno', interpolation='none')
axis[2, 3].set_title('Tuned EG Bishops (33)')
axis[3, 2].imshow(tuned_mg_rooks, cmap='inferno', interpolation='none')
axis[3, 2].set_title('Tuned MG Rooks (33)')
axis[3, 3].imshow(tuned_eg_rooks, cmap='inferno', interpolation='none')
axis[3, 3].set_title('Tuned EG Rooks (33)')
axis[4, 2].imshow(tuned_mg_queens, cmap='inferno', interpolation='none')
axis[4, 2].set_title('Tuned MG Queens (33)')
axis[4, 3].imshow(tuned_eg_queens, cmap='inferno', interpolation='none')
axis[4, 3].set_title('Tuned EG Queens (33)')
axis[5, 2].imshow(tuned_mg_kings, cmap='inferno', interpolation='none')
axis[5, 2].set_title('Tuned MG Kings (33)')
axis[5, 3].imshow(tuned_eg_kings, cmap='inferno', interpolation='none')
axis[5, 3].set_title('Tuned EG Kings (33)')
axis[0, 2 + 2].imshow(tuned_246_mg_pawns, cmap='inferno', interpolation='none')
axis[0, 2 + 2].set_title(f'Tuned MG Pawns ({it_2})')
axis[0, 3 + 2].imshow(tuned_246_eg_pawns, cmap='inferno', interpolation='none')
axis[0, 3 + 2].set_title(f'Tuned EG Pawns ({it_2})')
axis[1, 2 + 2].imshow(tuned_246_mg_knights, cmap='inferno', interpolation='none')
axis[1, 2 + 2].set_title(f'Tuned MG Knights ({it_2})')
axis[1, 3 + 2].imshow(tuned_246_eg_knights, cmap='inferno', interpolation='none')
axis[1, 3 + 2].set_title(f'Tuned EG Knights ({it_2})')
axis[2, 2 + 2].imshow(tuned_246_mg_bishops, cmap='inferno', interpolation='none')
axis[2, 2 + 2].set_title(f'Tuned MG Bishops ({it_2})')
axis[2, 3 + 2].imshow(tuned_246_eg_bishops, cmap='inferno', interpolation='none')
axis[2, 3 + 2].set_title(f'Tuned EG Bishops ({it_2})')
axis[3, 2 + 2].imshow(tuned_246_mg_rooks, cmap='inferno', interpolation='none')
axis[3, 2 + 2].set_title(f'Tuned MG Rooks ({it_2})')
axis[3, 3 + 2].imshow(tuned_246_eg_rooks, cmap='inferno', interpolation='none')
axis[3, 3 + 2].set_title(f'Tuned EG Rooks ({it_2})')
axis[4, 2 + 2].imshow(tuned_246_mg_queens, cmap='inferno', interpolation='none')
axis[4, 2 + 2].set_title(f'Tuned MG Queens ({it_2})')
axis[4, 3 + 2].imshow(tuned_246_eg_queens, cmap='inferno', interpolation='none')
axis[4, 3 + 2].set_title(f'Tuned EG Queens ({it_2})')
axis[5, 2 + 2].imshow(tuned_246_mg_kings, cmap='inferno', interpolation='none')
axis[5, 2 + 2].set_title(f'Tuned MG Kings ({it_2})')
axis[5, 3 + 2].imshow(tuned_246_eg_kings, cmap='inferno', interpolation='none')
axis[5, 3 + 2].set_title(f'Tuned EG Kings ({it_2})')
plt.show()
